# %%
import pandas as pd

# %%
deaths_states = pd.read_csv("../epidemic/deaths_state_21.csv")
death_states_monthly = deaths_states.copy()

# %%
deaths_states.head(1000)
# Out:
#          date            state  deaths_new  deaths_new_dod  deaths_bid  \
# 0    1/1/2021            Johor           0               1           0
# 1    1/1/2021            Kedah           0               0           0
# 2    1/1/2021         Kelantan           0               0           0
# 3    1/1/2021           Melaka           0               0           0
# 4    1/1/2021  Negeri Sembilan           1               2           0
# ..        ...              ...         ...             ...         ...
# 995  4/3/2021           Melaka           0               1           0
# 996  4/3/2021  Negeri Sembilan           0               0           0
# 997  4/3/2021           Pahang           1               0           0
# 998  4/3/2021            Perak           0               0           0
# 999  4/3/2021           Perlis           0               0           0
#
#      deaths_bid_dod  cumul_full  population
# 0                 0           0     3781000
# 1                 0           0     2185100
# 2                 0           0     1906700
# 3                 0           0      932700
# 4                 0           0     1128800
# ..              ...         ...         ...
# 995               0           0      932700
# 996               0           1     1128800
# 997               0           2     1678700
# 998               0           1     2510300
# 999               0           0      254900
#
# [1000 rows x 8 columns]

# %%
#Converts the data to deaths_new monthly average to avoid 0 values, same for cumul_full
deaths_states_monthly = deaths_states.groupby(['date', 'state'])[['deaths_new', 'cumul_full','population']].mean().reset_index()
deaths_states_monthly['date'] = pd.to_datetime(deaths_states_monthly['date'], format = "%d/%m/%Y")
deaths_states_monthly['date'] = deaths_states_monthly['date'].dt.to_period('M')
deaths_states_monthly.head(30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-190-8d070de24a31> in <module>
#       1 #Converts the data to deaths_new monthly average to avoid 0 values, same for cumul_full
# ----> 2 deaths_states_monthly['date'] = pd.to_datetime(deaths_states_monthly['date'], format = "%d/%m/%Y")
#       3 deaths_states_monthly = deaths_states.groupby(['date', 'state'])[['deaths_new', 'cumul_full','population']].mean().reset_index()
#       4 deaths_states_monthly['date'] = deaths_states_monthly['date'].dt.to_period('M')
#       5 deaths_states_monthly.head(30)
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     797                 result = result.tz_localize(tz)
#     798     elif isinstance(arg, ABCSeries):
# --> 799         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#     800         if not cache_array.empty:
#     801             result = arg.map(cache_array)
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _maybe_cache(arg, format, cache, convert_listlike)
#     168         unique_dates = unique(arg)
#     169         if len(unique_dates) < len(arg):
# --> 170             cache_dates = convert_listlike(unique_dates, format)
#     171             cache_array = Series(cache_dates, index=unique_dates)
#     172     return cache_array
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     369     orig_arg = arg
#     370     try:
# --> 371         arg, _ = maybe_convert_dtype(arg, copy=False)
#     372     except TypeError:
#     373         if errors == "coerce":
#
# ~\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in maybe_convert_dtype(data, copy)
#    2120         # Note: without explicitly raising here, PeriodIndex
#    2121         #  test_setops.test_join_does_not_recur fails
# -> 2122         raise TypeError(
#    2123             "Passing PeriodDtype data is invalid. Use `data.to_timestamp()` instead"
#    2124         )
#
# TypeError: Passing PeriodDtype data is invalid. Use `data.to_timestamp()` instead

# %%
#Finding out percentage cummulation for each state
deaths_states_monthly["cumul_full"] = pd.to_numeric(deaths_states_monthly['cumul_full'])
deaths_states_monthly["population"] = pd.to_numeric(deaths_states_monthly['population'])
deaths_states_monthly["percentage_vax"] = (deaths_states_monthly['cumul_full']/deaths_states_monthly['population']) * 100
deaths_states_monthly
# Out:
#          date              state  deaths_new  cumul_full  population  \
# 0     2021-01              Johor           0           0     3781000
# 1     2021-01              Kedah           0           0     2185100
# 2     2021-01           Kelantan           0           0     1906700
# 3     2021-01             Melaka           0           0      932700
# 4     2021-01    Negeri Sembilan           1           0     1128800
# ...       ...                ...         ...         ...         ...
# 4235  2021-09           Selangor          73     3724155     6538000
# 4236  2021-09         Terengganu           5      534041     1259300
# 4237  2021-09  W.P. Kuala Lumpur          25     2359938     1773700
# 4238  2021-09        W.P. Labuan           0       66615       99600
# 4239  2021-09     W.P. Putrajaya           0      120131      110000
#
#       percentage_vax
# 0           0.000000
# 1           0.000000
# 2           0.000000
# 3           0.000000
# 4           0.000000
# ...              ...
# 4235       56.961686
# 4236       42.407766
# 4237      133.051700
# 4238       66.882530
# 4239      109.210000
#
# [4240 rows x 6 columns]

# %%
deaths_states_monthly.to_csv("deaths_vax_states_monthly.csv")
